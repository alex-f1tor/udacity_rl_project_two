# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='./Reacher_Linux_v2/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

T = 8
episodes = 100000
# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
import torch
from ppo_agent20 import Agent
from collections import deque
           # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)

# %%
BUFFER_SIZE = int(1e6)  # replay buffer size
BATCH_SIZE = 512        # minibatch size
GAMMA = 0.9            # discount factor
LR_ACTOR = 5e-4         # learning rate of the actor 
LR_CRITIC = 1e-3        # learning rate of the critic
WEIGHT_DECAY = 0        # L2 weight decay
random_seed=10

# %%
import torch
episodes = 1200
from collections import namedtuple

# agent = Agent(state_size=state_size, action_size=action_size, random_seed=0)
# agent.actor_local.load_state_dict(torch.load('actor_net.chpt'))
# agent.critic_local.load_state_dict(torch.load('critic_net.chpt'))

reward_list = []

agent = Agent(state_size=state_size, action_size=action_size, random_seed=0)
scores_mean = deque(maxlen=1000)
scores = []
best_score = 0
best_average_score = 0
episodes=2000
max_steps=1000
Transition = namedtuple('Transition', ['state', 'action',  'a_log_prob', 'reward', 'next_state'])



for episode in range(1, episodes+1):

    env_info = env.reset(train_mode=True)[brain_name]     # reset the environment    
    cur_states = env_info.vector_observations  
    scores_agents = np.zeros(num_agents)      
    
    
    for step in range(max_steps):
        
        #should be added prbabilities to agent.step
        actions, probs = agent.act(cur_states)
        env_info = env.step(actions)[brain_name]     
        next_states = env_info.vector_observations   
        rewards = env_info.rewards                   
        dones = env_info.local_done                  
      
        trans = Transition(cur_states, actions, probs,  rewards, next_states)

        #should be added storing transitions
        #agent.step(, dones, step)
        
        agent.store_transition(trans)
        
        cur_states = next_states
        scores_agents += rewards
        if step>900:
            agent.learn(episode)
            break
    
    score = np.mean(scores_agents)
    scores_mean.append(score)
    average_score = np.mean(scores_mean)
    scores.append(score)
    if score > best_score:
        best_score = score
    if average_score > best_average_score:
        best_average_score = average_score
    print("Episode:{}, Average Score:{:.2f}".format(episode, average_score))
    if average_score > 30:
        torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
        torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
        print("Average score of 30 achieved")            
        break
    
env.close()
# Out:
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1147)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1, Average Score:0.51
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1016)
# val_loss tensor(1.00000e-02 *
#        9.5164)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:2, Average Score:0.38
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1031)
# val_loss tensor(1.00000e-02 *
#        8.8149)
# val_loss tensor(1.00000e-02 *
#        9.3679)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:3, Average Score:0.34
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.6821)
# val_loss tensor(1.00000e-02 *
#        9.2915)
# val_loss tensor(1.00000e-02 *
#        9.6842)
# val_loss tensor(1.00000e-02 *
#        8.9886)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:4, Average Score:0.34
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.9637)
# val_loss tensor(1.00000e-02 *
#        9.4103)
# val_loss tensor(1.00000e-02 *
#        9.4021)
# val_loss tensor(0.1086)
# val_loss tensor(1.00000e-02 *
#        9.5506)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:5, Average Score:0.36
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.7602)
# val_loss tensor(1.00000e-02 *
#        9.8503)
# val_loss tensor(0.1071)
# val_loss tensor(0.1013)
# val_loss tensor(1.00000e-02 *
#        9.2347)
# val_loss tensor(1.00000e-02 *
#        8.8940)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:6, Average Score:0.38
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1012)
# val_loss tensor(1.00000e-02 *
#        9.6678)
# val_loss tensor(0.1021)
# val_loss tensor(0.1055)
# val_loss tensor(1.00000e-02 *
#        9.6055)
# val_loss tensor(0.1131)
# val_loss tensor(1.00000e-02 *
#        9.5020)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:7, Average Score:0.44
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.0158)
# val_loss tensor(1.00000e-02 *
#        9.3975)
# val_loss tensor(1.00000e-02 *
#        9.3896)
# val_loss tensor(1.00000e-02 *
#        9.5000)
# val_loss tensor(1.00000e-02 *
#        9.0008)
# val_loss tensor(1.00000e-02 *
#        8.9106)
# val_loss tensor(0.1097)
# val_loss tensor(1.00000e-02 *
#        9.9931)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:8, Average Score:0.42
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.9359)
# val_loss tensor(1.00000e-02 *
#        8.2457)
# val_loss tensor(1.00000e-02 *
#        8.1443)
# val_loss tensor(1.00000e-02 *
#        7.9986)
# val_loss tensor(1.00000e-02 *
#        8.7604)
# val_loss tensor(1.00000e-02 *
#        8.5946)
# val_loss tensor(1.00000e-02 *
#        8.1081)
# val_loss tensor(1.00000e-02 *
#        6.9432)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:9, Average Score:0.44
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.1338)
# val_loss tensor(1.00000e-02 *
#        6.3791)
# val_loss tensor(1.00000e-02 *
#        5.9438)
# val_loss tensor(1.00000e-02 *
#        6.3684)
# val_loss tensor(1.00000e-02 *
#        5.7629)
# val_loss tensor(1.00000e-02 *
#        6.2197)
# val_loss tensor(1.00000e-02 *
#        5.3364)
# val_loss tensor(1.00000e-02 *
#        5.3166)
# val_loss tensor(1.00000e-02 *
#        5.5499)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:10, Average Score:0.44
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1075)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:11, Average Score:0.46
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1097)
# val_loss tensor(0.1157)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:12, Average Score:0.46
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1024)
# val_loss tensor(0.1104)
# val_loss tensor(0.1006)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:13, Average Score:0.48
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1127)
# val_loss tensor(0.1069)
# val_loss tensor(0.1082)
# val_loss tensor(0.1132)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:14, Average Score:0.48
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1395)
# val_loss tensor(0.1474)
# val_loss tensor(0.1406)
# val_loss tensor(0.1492)
# val_loss tensor(0.1549)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:15, Average Score:0.50
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1715)
# val_loss tensor(0.1582)
# val_loss tensor(0.1803)
# val_loss tensor(0.1661)
# val_loss tensor(0.1750)
# val_loss tensor(0.1879)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:16, Average Score:0.52
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2279)
# val_loss tensor(0.2144)
# val_loss tensor(0.2121)
# val_loss tensor(0.2165)
# val_loss tensor(0.2077)
# val_loss tensor(0.2069)
# val_loss tensor(0.2047)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:17, Average Score:0.54
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2482)
# val_loss tensor(0.2685)
# val_loss tensor(0.2474)
# val_loss tensor(0.2444)
# val_loss tensor(0.2408)
# val_loss tensor(0.2360)
# val_loss tensor(0.2327)
# val_loss tensor(0.2192)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:18, Average Score:0.56
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2607)
# val_loss tensor(0.2750)
# val_loss tensor(0.2761)
# val_loss tensor(0.2595)
# val_loss tensor(0.2715)
# val_loss tensor(0.2698)
# val_loss tensor(0.2547)
# val_loss tensor(0.2720)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:19, Average Score:0.59
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2813)
# val_loss tensor(0.2838)
# val_loss tensor(0.3165)
# val_loss tensor(0.3041)
# val_loss tensor(0.2945)
# val_loss tensor(0.2920)
# val_loss tensor(0.3032)
# val_loss tensor(0.2914)
# val_loss tensor(0.3043)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:20, Average Score:0.61
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5551)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:21, Average Score:0.63
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5176)
# val_loss tensor(0.4992)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:22, Average Score:0.66
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5348)
# val_loss tensor(0.5266)
# val_loss tensor(0.5117)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:23, Average Score:0.70
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5176)
# val_loss tensor(0.5623)
# val_loss tensor(0.5194)
# val_loss tensor(0.5476)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:24, Average Score:0.74
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5379)
# val_loss tensor(0.5318)
# val_loss tensor(0.5326)
# val_loss tensor(0.5178)
# val_loss tensor(0.5414)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:25, Average Score:0.76
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5110)
# val_loss tensor(0.5247)
# val_loss tensor(0.5285)
# val_loss tensor(0.5399)
# val_loss tensor(0.5364)
# val_loss tensor(0.5392)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:26, Average Score:0.78
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5167)
# val_loss tensor(0.5208)
# val_loss tensor(0.5370)
# val_loss tensor(0.5524)
# val_loss tensor(0.5008)
# val_loss tensor(0.5494)
# val_loss tensor(0.5382)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:27, Average Score:0.80
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5349)
# val_loss tensor(0.5249)
# val_loss tensor(0.5258)
# val_loss tensor(0.5593)
# val_loss tensor(0.5267)
# val_loss tensor(0.5288)
# val_loss tensor(0.5205)
# val_loss tensor(0.5675)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:28, Average Score:0.82
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5190)
# val_loss tensor(0.5012)
# val_loss tensor(0.4966)
# val_loss tensor(0.4984)
# val_loss tensor(0.4950)
# val_loss tensor(0.5202)
# val_loss tensor(0.5025)
# val_loss tensor(0.4996)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:29, Average Score:0.83
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5190)
# val_loss tensor(0.4782)
# val_loss tensor(0.5040)
# val_loss tensor(0.4991)
# val_loss tensor(0.4959)
# val_loss tensor(0.4955)
# val_loss tensor(0.4958)
# val_loss tensor(0.4841)
# val_loss tensor(0.4986)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:30, Average Score:0.85
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5876)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:31, Average Score:0.87
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5057)
# val_loss tensor(0.5113)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:32, Average Score:0.89
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5595)
# val_loss tensor(0.5144)
# val_loss tensor(0.5195)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:33, Average Score:0.90
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5203)
# val_loss tensor(0.5195)
# val_loss tensor(0.5212)
# val_loss tensor(0.5176)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:34, Average Score:0.92
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4998)
# val_loss tensor(0.5129)
# val_loss tensor(0.5077)
# val_loss tensor(0.4919)
# val_loss tensor(0.5153)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:35, Average Score:0.93
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4884)
# val_loss tensor(0.5041)
# val_loss tensor(0.4899)
# val_loss tensor(0.4952)
# val_loss tensor(0.4933)
# val_loss tensor(0.4832)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:36, Average Score:0.93
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4799)
# val_loss tensor(0.4802)
# val_loss tensor(0.4904)
# val_loss tensor(0.4762)
# val_loss tensor(0.4894)
# val_loss tensor(0.5099)
# val_loss tensor(0.5009)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:37, Average Score:0.92
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4776)
# val_loss tensor(0.4818)
# val_loss tensor(0.4854)
# val_loss tensor(0.4824)
# val_loss tensor(0.4761)
# val_loss tensor(0.4854)
# val_loss tensor(0.4946)
# val_loss tensor(0.4536)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:38, Average Score:0.92
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4784)
# val_loss tensor(0.4700)
# val_loss tensor(0.4653)
# val_loss tensor(0.4885)
# val_loss tensor(0.4731)
# val_loss tensor(0.4479)
# val_loss tensor(0.4820)
# val_loss tensor(0.4609)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:39, Average Score:0.92
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4960)
# val_loss tensor(0.4864)
# val_loss tensor(0.4951)
# val_loss tensor(0.5219)
# val_loss tensor(0.5140)
# val_loss tensor(0.4749)
# val_loss tensor(0.5002)
# val_loss tensor(0.4719)
# val_loss tensor(0.5085)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:40, Average Score:0.93
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5470)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:41, Average Score:0.93
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4724)
# val_loss tensor(0.4886)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:42, Average Score:0.94
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4692)
# val_loss tensor(0.4591)
# val_loss tensor(0.4361)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:43, Average Score:0.94
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4483)
# val_loss tensor(0.4318)
# val_loss tensor(0.4486)
# val_loss tensor(0.4541)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:44, Average Score:0.95
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4406)
# val_loss tensor(0.4642)
# val_loss tensor(0.4669)
# val_loss tensor(0.4314)
# val_loss tensor(0.4739)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:45, Average Score:0.95
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4695)
# val_loss tensor(0.4544)
# val_loss tensor(0.4486)
# val_loss tensor(0.4633)
# val_loss tensor(0.4574)
# val_loss tensor(0.4392)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:46, Average Score:0.95
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4770)
# val_loss tensor(0.4531)
# val_loss tensor(0.4701)
# val_loss tensor(0.4660)
# val_loss tensor(0.4494)
# val_loss tensor(0.4570)
# val_loss tensor(0.4641)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:47, Average Score:0.96
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4915)
# val_loss tensor(0.4894)
# val_loss tensor(0.4554)
# val_loss tensor(0.4892)
# val_loss tensor(0.4638)
# val_loss tensor(0.4704)
# val_loss tensor(0.4686)
# val_loss tensor(0.6141)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:48, Average Score:0.97
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4851)
# val_loss tensor(0.5038)
# val_loss tensor(0.4985)
# val_loss tensor(0.4751)
# val_loss tensor(0.4882)
# val_loss tensor(0.4730)
# val_loss tensor(0.4817)
# val_loss tensor(0.4702)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:49, Average Score:0.97
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5267)
# val_loss tensor(0.4870)
# val_loss tensor(0.5039)
# val_loss tensor(0.4756)
# val_loss tensor(0.4927)
# val_loss tensor(0.5046)
# val_loss tensor(0.4870)
# val_loss tensor(0.4870)
# val_loss tensor(0.4988)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:50, Average Score:0.99
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5677)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:51, Average Score:1.00
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5400)
# val_loss tensor(0.5447)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:52, Average Score:1.00
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5347)
# val_loss tensor(0.5542)
# val_loss tensor(0.5349)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:53, Average Score:1.01
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5507)
# val_loss tensor(0.5584)
# val_loss tensor(0.5581)
# val_loss tensor(0.5904)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:54, Average Score:1.03
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5622)
# val_loss tensor(0.5566)
# val_loss tensor(0.5709)
# val_loss tensor(0.5711)
# val_loss tensor(0.5504)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:55, Average Score:1.04
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5765)
# val_loss tensor(0.5880)
# val_loss tensor(0.5879)
# val_loss tensor(0.5937)
# val_loss tensor(0.5895)
# val_loss tensor(0.6323)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:56, Average Score:1.05
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5762)
# val_loss tensor(0.5698)
# val_loss tensor(0.5687)
# val_loss tensor(0.5849)
# val_loss tensor(0.5691)
# val_loss tensor(0.5584)
# val_loss tensor(0.5655)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:57, Average Score:1.06
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5697)
# val_loss tensor(0.5433)
# val_loss tensor(0.5633)
# val_loss tensor(0.5612)
# val_loss tensor(0.5389)
# val_loss tensor(0.5428)
# val_loss tensor(0.5775)
# val_loss tensor(0.5743)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:58, Average Score:1.05
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5832)
# val_loss tensor(0.5659)
# val_loss tensor(0.5580)
# val_loss tensor(0.5757)
# val_loss tensor(0.5808)
# val_loss tensor(0.5899)
# val_loss tensor(0.5489)
# val_loss tensor(0.5678)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:59, Average Score:1.06
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5831)
# val_loss tensor(0.5735)
# val_loss tensor(0.5708)
# val_loss tensor(0.5825)
# val_loss tensor(0.5995)
# val_loss tensor(0.5690)
# val_loss tensor(0.5852)
# val_loss tensor(0.5824)
# val_loss tensor(0.5876)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:60, Average Score:1.06
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6540)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:61, Average Score:1.06
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6228)
# val_loss tensor(0.5740)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:62, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6139)
# val_loss tensor(0.6133)
# val_loss tensor(0.5793)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:63, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5840)
# val_loss tensor(0.5855)
# val_loss tensor(0.5857)
# val_loss tensor(0.5660)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:64, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5951)
# val_loss tensor(0.5906)
# val_loss tensor(0.5872)
# val_loss tensor(0.6100)
# val_loss tensor(0.6136)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:65, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5893)
# val_loss tensor(0.5838)
# val_loss tensor(0.5870)
# val_loss tensor(0.5712)
# val_loss tensor(0.5820)
# val_loss tensor(0.5987)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:66, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5845)
# val_loss tensor(0.5626)
# val_loss tensor(0.5775)
# val_loss tensor(0.5802)
# val_loss tensor(0.5770)
# val_loss tensor(0.5889)
# val_loss tensor(0.5896)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:67, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5780)
# val_loss tensor(0.5898)
# val_loss tensor(0.5843)
# val_loss tensor(0.5811)
# val_loss tensor(0.5809)
# val_loss tensor(0.5853)
# val_loss tensor(0.5595)
# val_loss tensor(0.5975)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:68, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5355)
# val_loss tensor(0.5482)
# val_loss tensor(0.5508)
# val_loss tensor(0.5376)
# val_loss tensor(0.5448)
# val_loss tensor(0.5294)
# val_loss tensor(0.5573)
# val_loss tensor(0.5333)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:69, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.5730)
# val_loss tensor(0.5399)
# val_loss tensor(0.5531)
# val_loss tensor(0.5492)
# val_loss tensor(0.5667)
# val_loss tensor(0.5597)
# val_loss tensor(0.5435)
# val_loss tensor(0.5371)
# val_loss tensor(0.5581)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:70, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.7603)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:71, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6665)
# val_loss tensor(0.6443)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:72, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6316)
# val_loss tensor(0.6319)
# val_loss tensor(0.6444)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:73, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6880)
# val_loss tensor(0.6999)
# val_loss tensor(0.6763)
# val_loss tensor(0.6807)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:74, Average Score:1.08
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6838)
# val_loss tensor(0.7484)
# val_loss tensor(0.7453)
# val_loss tensor(0.6608)
# val_loss tensor(0.6880)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:75, Average Score:1.08
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.7917)
# val_loss tensor(0.7602)
# val_loss tensor(0.6491)
# val_loss tensor(0.6853)
# val_loss tensor(0.7641)
# val_loss tensor(0.7474)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:76, Average Score:1.08
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6663)
# val_loss tensor(0.6950)
# val_loss tensor(0.7180)
# val_loss tensor(0.6836)
# val_loss tensor(0.6915)
# val_loss tensor(0.7138)
# val_loss tensor(0.7380)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:77, Average Score:1.08
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6762)
# val_loss tensor(0.6801)
# val_loss tensor(0.6454)
# val_loss tensor(0.6534)
# val_loss tensor(0.6463)
# val_loss tensor(0.6397)
# val_loss tensor(0.6574)
# val_loss tensor(0.6958)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:78, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6760)
# val_loss tensor(0.6722)
# val_loss tensor(0.6643)
# val_loss tensor(0.6639)
# val_loss tensor(0.6681)
# val_loss tensor(0.6818)
# val_loss tensor(0.6527)
# val_loss tensor(0.6864)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:79, Average Score:1.07
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6617)
# val_loss tensor(0.6725)
# val_loss tensor(0.6762)
# val_loss tensor(0.6679)
# val_loss tensor(0.6723)
# val_loss tensor(0.6840)
# val_loss tensor(0.6605)
# val_loss tensor(0.6876)
# val_loss tensor(0.6794)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:80, Average Score:1.06
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.7817)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:81, Average Score:1.05
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.6421)
# val_loss tensor(0.6195)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:82, Average Score:1.04
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4916)
# val_loss tensor(0.4854)
# val_loss tensor(0.4996)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:83, Average Score:1.03
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.4055)
# val_loss tensor(0.3727)
# val_loss tensor(0.4025)
# val_loss tensor(0.3958)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:84, Average Score:1.02
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.3543)
# val_loss tensor(0.3568)
# val_loss tensor(0.3522)
# val_loss tensor(0.3600)
# val_loss tensor(0.3498)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:85, Average Score:1.01
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.3415)
# val_loss tensor(0.3590)
# val_loss tensor(0.3498)
# val_loss tensor(0.3309)
# val_loss tensor(0.3378)
# val_loss tensor(0.3362)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:86, Average Score:1.00
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2907)
# val_loss tensor(0.2748)
# val_loss tensor(0.2877)
# val_loss tensor(0.2838)
# val_loss tensor(0.2807)
# val_loss tensor(0.2946)
# val_loss tensor(0.2733)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:87, Average Score:0.98
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2798)
# val_loss tensor(0.2842)
# val_loss tensor(0.2806)
# val_loss tensor(0.2757)
# val_loss tensor(0.2563)
# val_loss tensor(0.2848)
# val_loss tensor(0.2687)
# val_loss tensor(0.2905)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:88, Average Score:0.98
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2638)
# val_loss tensor(0.2618)
# val_loss tensor(0.2604)
# val_loss tensor(0.2685)
# val_loss tensor(0.2686)
# val_loss tensor(0.2650)
# val_loss tensor(0.2681)
# val_loss tensor(0.2721)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:89, Average Score:0.97
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2482)
# val_loss tensor(0.2499)
# val_loss tensor(0.2532)
# val_loss tensor(0.2449)
# val_loss tensor(0.2506)
# val_loss tensor(0.2458)
# val_loss tensor(0.2371)
# val_loss tensor(0.2450)
# val_loss tensor(0.2381)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:90, Average Score:0.96
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2248)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:91, Average Score:0.95
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.2085)
# val_loss tensor(0.2067)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:92, Average Score:0.94
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1883)
# val_loss tensor(0.1859)
# val_loss tensor(0.1999)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:93, Average Score:0.93
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1734)
# val_loss tensor(0.1693)
# val_loss tensor(0.1874)
# val_loss tensor(0.1805)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:94, Average Score:0.92
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1730)
# val_loss tensor(0.1654)
# val_loss tensor(0.1714)
# val_loss tensor(0.1769)
# val_loss tensor(0.1561)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:95, Average Score:0.91
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1552)
# val_loss tensor(0.1595)
# val_loss tensor(0.1607)
# val_loss tensor(0.1667)
# val_loss tensor(0.1679)
# val_loss tensor(0.1517)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:96, Average Score:0.90
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1590)
# val_loss tensor(0.1630)
# val_loss tensor(0.1608)
# val_loss tensor(0.1666)
# val_loss tensor(0.1692)
# val_loss tensor(0.1647)
# val_loss tensor(0.1260)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:97, Average Score:0.89
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1642)
# val_loss tensor(0.1515)
# val_loss tensor(0.1655)
# val_loss tensor(0.1514)
# val_loss tensor(0.1717)
# val_loss tensor(0.1696)
# val_loss tensor(0.1740)
# val_loss tensor(0.2219)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:98, Average Score:0.89
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1711)
# val_loss tensor(0.1401)
# val_loss tensor(0.1606)
# val_loss tensor(0.1551)
# val_loss tensor(0.1542)
# val_loss tensor(0.1568)
# val_loss tensor(0.1548)
# val_loss tensor(0.1573)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:99, Average Score:0.88
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1656)
# val_loss tensor(0.1431)
# val_loss tensor(0.1673)
# val_loss tensor(0.1480)
# val_loss tensor(0.1619)
# val_loss tensor(0.1443)
# val_loss tensor(0.1538)
# val_loss tensor(0.1421)
# val_loss tensor(0.1511)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:100, Average Score:0.87
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1611)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:101, Average Score:0.86
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1249)
# val_loss tensor(0.1240)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:102, Average Score:0.85
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1223)
# val_loss tensor(0.1186)
# val_loss tensor(0.1074)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:103, Average Score:0.85
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1058)
# val_loss tensor(0.1086)
# val_loss tensor(0.1111)
# val_loss tensor(0.1205)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:104, Average Score:0.84
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1130)
# val_loss tensor(0.1205)
# val_loss tensor(1.00000e-02 *
#        9.8895)
# val_loss tensor(0.1075)
# val_loss tensor(0.1022)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:105, Average Score:0.83
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1157)
# val_loss tensor(0.1111)
# val_loss tensor(1.00000e-02 *
#        9.8955)
# val_loss tensor(1.00000e-02 *
#        9.6708)
# val_loss tensor(0.1014)
# val_loss tensor(1.00000e-02 *
#        9.5440)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:106, Average Score:0.82
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1321)
# val_loss tensor(0.1116)
# val_loss tensor(0.1241)
# val_loss tensor(0.1248)
# val_loss tensor(0.1309)
# val_loss tensor(0.1143)
# val_loss tensor(0.1146)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:107, Average Score:0.82
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1433)
# val_loss tensor(0.1310)
# val_loss tensor(0.1235)
# val_loss tensor(0.1169)
# val_loss tensor(0.1328)
# val_loss tensor(0.1289)
# val_loss tensor(0.1121)
# val_loss tensor(1.00000e-02 *
#        6.1994)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:108, Average Score:0.81
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1172)
# val_loss tensor(0.1199)
# val_loss tensor(0.1361)
# val_loss tensor(0.1250)
# val_loss tensor(0.1238)
# val_loss tensor(0.1165)
# val_loss tensor(0.1361)
# val_loss tensor(0.1237)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:109, Average Score:0.81
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1128)
# val_loss tensor(0.1337)
# val_loss tensor(0.1314)
# val_loss tensor(0.1342)
# val_loss tensor(0.1552)
# val_loss tensor(0.1357)
# val_loss tensor(0.1328)
# val_loss tensor(0.1451)
# val_loss tensor(0.1340)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:110, Average Score:0.80
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1636)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:111, Average Score:0.79
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1218)
# val_loss tensor(0.1288)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:112, Average Score:0.79
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1172)
# val_loss tensor(0.1187)
# val_loss tensor(0.1004)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:113, Average Score:0.78
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1277)
# val_loss tensor(0.1094)
# val_loss tensor(0.1165)
# val_loss tensor(0.1131)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:114, Average Score:0.77
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1137)
# val_loss tensor(0.1084)
# val_loss tensor(0.1221)
# val_loss tensor(0.1084)
# val_loss tensor(0.1284)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:115, Average Score:0.77
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1198)
# val_loss tensor(0.1232)
# val_loss tensor(0.1178)
# val_loss tensor(0.1113)
# val_loss tensor(0.1057)
# val_loss tensor(0.1717)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:116, Average Score:0.76
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1323)
# val_loss tensor(0.1275)
# val_loss tensor(0.1211)
# val_loss tensor(0.1248)
# val_loss tensor(0.1270)
# val_loss tensor(0.1246)
# val_loss tensor(0.1459)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:117, Average Score:0.76
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1294)
# val_loss tensor(0.1316)
# val_loss tensor(0.1307)
# val_loss tensor(0.1178)
# val_loss tensor(0.1326)
# val_loss tensor(0.1381)
# val_loss tensor(0.1457)
# val_loss tensor(0.2322)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:118, Average Score:0.75
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1397)
# val_loss tensor(0.1265)
# val_loss tensor(0.1323)
# val_loss tensor(0.1200)
# val_loss tensor(0.1537)
# val_loss tensor(0.1501)
# val_loss tensor(0.1468)
# val_loss tensor(0.1541)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:119, Average Score:0.75
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1431)
# val_loss tensor(0.1325)
# val_loss tensor(0.1494)
# val_loss tensor(0.1652)
# val_loss tensor(0.1300)
# val_loss tensor(0.1390)
# val_loss tensor(0.1449)
# val_loss tensor(0.1555)
# val_loss tensor(0.1389)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:120, Average Score:0.74
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1378)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:121, Average Score:0.74
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1147)
# val_loss tensor(0.1116)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:122, Average Score:0.73
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1324)
# val_loss tensor(0.1299)
# val_loss tensor(0.1199)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:123, Average Score:0.72
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1179)
# val_loss tensor(0.1236)
# val_loss tensor(0.1042)
# val_loss tensor(0.1215)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:124, Average Score:0.72
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.9867)
# val_loss tensor(1.00000e-02 *
#        9.3739)
# val_loss tensor(0.1118)
# val_loss tensor(0.1153)
# val_loss tensor(0.1138)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:125, Average Score:0.71
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1027)
# val_loss tensor(0.1085)
# val_loss tensor(0.1031)
# val_loss tensor(0.1080)
# val_loss tensor(0.1023)
# val_loss tensor(1.00000e-02 *
#        7.5005)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:126, Average Score:0.71
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1011)
# val_loss tensor(1.00000e-02 *
#        8.7665)
# val_loss tensor(1.00000e-02 *
#        9.1846)
# val_loss tensor(0.1070)
# val_loss tensor(1.00000e-02 *
#        9.5010)
# val_loss tensor(0.1104)
# val_loss tensor(1.00000e-02 *
#        7.6888)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:127, Average Score:0.70
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.2059)
# val_loss tensor(1.00000e-02 *
#        9.8773)
# val_loss tensor(1.00000e-02 *
#        9.1601)
# val_loss tensor(0.1029)
# val_loss tensor(1.00000e-02 *
#        7.8482)
# val_loss tensor(1.00000e-02 *
#        9.8269)
# val_loss tensor(1.00000e-02 *
#        9.2958)
# val_loss tensor(1.00000e-02 *
#        1.9404)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:128, Average Score:0.70
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.9011)
# val_loss tensor(0.1022)
# val_loss tensor(0.1015)
# val_loss tensor(0.1058)
# val_loss tensor(1.00000e-02 *
#        9.3317)
# val_loss tensor(1.00000e-02 *
#        9.3494)
# val_loss tensor(0.1004)
# val_loss tensor(0.1012)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:129, Average Score:0.70
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.9804)
# val_loss tensor(1.00000e-02 *
#        8.8136)
# val_loss tensor(1.00000e-02 *
#        8.6675)
# val_loss tensor(1.00000e-02 *
#        9.9400)
# val_loss tensor(1.00000e-02 *
#        8.3691)
# val_loss tensor(1.00000e-02 *
#        8.9739)
# val_loss tensor(1.00000e-02 *
#        9.7058)
# val_loss tensor(1.00000e-02 *
#        9.0410)
# val_loss tensor(0.1030)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:130, Average Score:0.69
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1102)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:131, Average Score:0.69
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.5032)
# val_loss tensor(1.00000e-02 *
#        7.9783)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:132, Average Score:0.68
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.6572)
# val_loss tensor(1.00000e-02 *
#        7.0234)
# val_loss tensor(1.00000e-02 *
#        7.4174)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:133, Average Score:0.68
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.7260)
# val_loss tensor(1.00000e-02 *
#        7.5788)
# val_loss tensor(1.00000e-02 *
#        9.1068)
# val_loss tensor(1.00000e-02 *
#        6.5731)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:134, Average Score:0.67
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.9018)
# val_loss tensor(1.00000e-02 *
#        7.9920)
# val_loss tensor(1.00000e-02 *
#        7.1508)
# val_loss tensor(1.00000e-02 *
#        8.5125)
# val_loss tensor(1.00000e-02 *
#        9.7915)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:135, Average Score:0.67
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.1526)
# val_loss tensor(1.00000e-02 *
#        9.9596)
# val_loss tensor(1.00000e-02 *
#        9.7588)
# val_loss tensor(1.00000e-02 *
#        8.4554)
# val_loss tensor(0.1012)
# val_loss tensor(0.1297)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:136, Average Score:0.66
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1101)
# val_loss tensor(1.00000e-02 *
#        9.3573)
# val_loss tensor(1.00000e-02 *
#        9.5406)
# val_loss tensor(1.00000e-02 *
#        9.0797)
# val_loss tensor(1.00000e-02 *
#        8.3932)
# val_loss tensor(1.00000e-02 *
#        9.1261)
# val_loss tensor(0.1009)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:137, Average Score:0.66
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1084)
# val_loss tensor(1.00000e-02 *
#        9.9580)
# val_loss tensor(1.00000e-02 *
#        9.1048)
# val_loss tensor(0.1032)
# val_loss tensor(1.00000e-02 *
#        7.6993)
# val_loss tensor(1.00000e-02 *
#        8.7851)
# val_loss tensor(1.00000e-02 *
#        9.6821)
# val_loss tensor(0.1530)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:138, Average Score:0.65
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1112)
# val_loss tensor(0.1069)
# val_loss tensor(1.00000e-02 *
#        9.3688)
# val_loss tensor(1.00000e-02 *
#        9.9692)
# val_loss tensor(0.1016)
# val_loss tensor(0.1004)
# val_loss tensor(0.1117)
# val_loss tensor(1.00000e-02 *
#        9.9526)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:139, Average Score:0.65
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.7671)
# val_loss tensor(0.1181)
# val_loss tensor(1.00000e-02 *
#        9.7694)
# val_loss tensor(0.1047)
# val_loss tensor(0.1131)
# val_loss tensor(0.1011)
# val_loss tensor(0.1215)
# val_loss tensor(0.1192)
# val_loss tensor(0.1383)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:140, Average Score:0.65
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1512)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:141, Average Score:0.64
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1572)
# val_loss tensor(0.1439)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:142, Average Score:0.64
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1392)
# val_loss tensor(0.1282)
# val_loss tensor(0.1327)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:143, Average Score:0.64
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1140)
# val_loss tensor(0.1028)
# val_loss tensor(0.1207)
# val_loss tensor(1.00000e-02 *
#        9.7426)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:144, Average Score:0.63
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1096)
# val_loss tensor(0.1049)
# val_loss tensor(0.1066)
# val_loss tensor(0.1112)
# val_loss tensor(0.1001)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:145, Average Score:0.63
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1204)
# val_loss tensor(0.1036)
# val_loss tensor(0.1340)
# val_loss tensor(0.1062)
# val_loss tensor(0.1246)
# val_loss tensor(1.00000e-02 *
#        9.6803)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:146, Average Score:0.62
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1129)
# val_loss tensor(0.1365)
# val_loss tensor(0.1252)
# val_loss tensor(0.1474)
# val_loss tensor(0.1413)
# val_loss tensor(0.1353)
# val_loss tensor(0.1396)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:147, Average Score:0.62
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1667)
# val_loss tensor(0.1610)
# val_loss tensor(0.1445)
# val_loss tensor(0.1364)
# val_loss tensor(0.1674)
# val_loss tensor(0.1391)
# val_loss tensor(0.1646)
# val_loss tensor(0.1240)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:148, Average Score:0.62
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1684)
# val_loss tensor(0.1600)
# val_loss tensor(0.1982)
# val_loss tensor(0.1533)
# val_loss tensor(0.1706)
# val_loss tensor(0.1452)
# val_loss tensor(0.1492)
# val_loss tensor(0.1694)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:149, Average Score:0.61
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1629)
# val_loss tensor(0.1816)
# val_loss tensor(0.1760)
# val_loss tensor(0.1467)
# val_loss tensor(0.1482)
# val_loss tensor(0.1806)
# val_loss tensor(0.1669)
# val_loss tensor(0.1558)
# val_loss tensor(0.1686)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:150, Average Score:0.61
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1717)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:151, Average Score:0.61
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1532)
# val_loss tensor(0.1450)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:152, Average Score:0.60
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1288)
# val_loss tensor(0.1504)
# val_loss tensor(0.1342)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:153, Average Score:0.60
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1009)
# val_loss tensor(0.1122)
# val_loss tensor(0.1249)
# val_loss tensor(0.1325)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:154, Average Score:0.60
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1286)
# val_loss tensor(0.1392)
# val_loss tensor(0.1136)
# val_loss tensor(0.1182)
# val_loss tensor(0.1060)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:155, Average Score:0.59
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1148)
# val_loss tensor(1.00000e-02 *
#        9.6141)
# val_loss tensor(0.1028)
# val_loss tensor(0.1297)
# val_loss tensor(0.1169)
# val_loss tensor(0.1379)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:156, Average Score:0.59
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1134)
# val_loss tensor(0.1353)
# val_loss tensor(0.1265)
# val_loss tensor(0.1143)
# val_loss tensor(1.00000e-02 *
#        9.7380)
# val_loss tensor(0.1079)
# val_loss tensor(0.1664)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:157, Average Score:0.59
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1246)
# val_loss tensor(0.1402)
# val_loss tensor(0.1347)
# val_loss tensor(0.1305)
# val_loss tensor(0.1426)
# val_loss tensor(0.1231)
# val_loss tensor(0.1199)
# val_loss tensor(0.1016)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:158, Average Score:0.58
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1246)
# val_loss tensor(0.1060)
# val_loss tensor(0.1244)
# val_loss tensor(0.1294)
# val_loss tensor(0.1148)
# val_loss tensor(0.1436)
# val_loss tensor(0.1124)
# val_loss tensor(0.1144)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:159, Average Score:0.58
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1344)
# val_loss tensor(0.1013)
# val_loss tensor(0.1272)
# val_loss tensor(0.1295)
# val_loss tensor(0.1226)
# val_loss tensor(0.1256)
# val_loss tensor(0.1120)
# val_loss tensor(0.1241)
# val_loss tensor(0.1241)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:160, Average Score:0.58
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1598)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:161, Average Score:0.57
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1546)
# val_loss tensor(0.1516)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:162, Average Score:0.57
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1113)
# val_loss tensor(0.1070)
# val_loss tensor(0.1142)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:163, Average Score:0.57
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1165)
# val_loss tensor(0.1023)
# val_loss tensor(0.1000)
# val_loss tensor(1.00000e-02 *
#        9.4311)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:164, Average Score:0.57
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.7290)
# val_loss tensor(0.1131)
# val_loss tensor(0.1167)
# val_loss tensor(0.1034)
# val_loss tensor(0.1108)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:165, Average Score:0.56
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1068)
# val_loss tensor(0.1058)
# val_loss tensor(0.1006)
# val_loss tensor(0.1036)
# val_loss tensor(0.1038)
# val_loss tensor(0.1168)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:166, Average Score:0.56
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1106)
# val_loss tensor(1.00000e-02 *
#        9.4039)
# val_loss tensor(1.00000e-02 *
#        9.0559)
# val_loss tensor(1.00000e-02 *
#        9.1363)
# val_loss tensor(1.00000e-02 *
#        8.8293)
# val_loss tensor(1.00000e-02 *
#        9.4081)
# val_loss tensor(1.00000e-02 *
#        9.3990)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:167, Average Score:0.56
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1132)
# val_loss tensor(1.00000e-02 *
#        9.7780)
# val_loss tensor(0.1001)
# val_loss tensor(0.1110)
# val_loss tensor(0.1207)
# val_loss tensor(0.1022)
# val_loss tensor(0.1079)
# val_loss tensor(0.2094)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:168, Average Score:0.55
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1111)
# val_loss tensor(0.1204)
# val_loss tensor(0.1131)
# val_loss tensor(0.1272)
# val_loss tensor(1.00000e-02 *
#        9.0252)
# val_loss tensor(0.1102)
# val_loss tensor(0.1018)
# val_loss tensor(1.00000e-02 *
#        7.8621)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:169, Average Score:0.55
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1048)
# val_loss tensor(0.1153)
# val_loss tensor(0.1076)
# val_loss tensor(0.1277)
# val_loss tensor(0.1229)
# val_loss tensor(0.1141)
# val_loss tensor(0.1006)
# val_loss tensor(0.1152)
# val_loss tensor(0.1249)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:170, Average Score:0.55
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1496)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:171, Average Score:0.55
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.5060)
# val_loss tensor(1.00000e-02 *
#        8.8325)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:172, Average Score:0.54
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1054)
# val_loss tensor(1.00000e-02 *
#        9.3878)
# val_loss tensor(0.1020)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:173, Average Score:0.54
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.9723)
# val_loss tensor(1.00000e-02 *
#        9.4410)
# val_loss tensor(0.1150)
# val_loss tensor(1.00000e-02 *
#        8.4311)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:174, Average Score:0.54
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.5326)
# val_loss tensor(0.1099)
# val_loss tensor(1.00000e-02 *
#        8.1547)
# val_loss tensor(1.00000e-02 *
#        8.2512)
# val_loss tensor(1.00000e-02 *
#        8.7221)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:175, Average Score:0.54
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.3772)
# val_loss tensor(0.1020)
# val_loss tensor(1.00000e-02 *
#        9.5620)
# val_loss tensor(0.1040)
# val_loss tensor(1.00000e-02 *
#        7.5515)
# val_loss tensor(1.00000e-02 *
#        8.3696)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:176, Average Score:0.53
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.0442)
# val_loss tensor(0.1112)
# val_loss tensor(1.00000e-02 *
#        9.5186)
# val_loss tensor(0.1105)
# val_loss tensor(0.1039)
# val_loss tensor(1.00000e-02 *
#        8.9416)
# val_loss tensor(0.1328)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:177, Average Score:0.53
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1191)
# val_loss tensor(1.00000e-02 *
#        8.3464)
# val_loss tensor(1.00000e-02 *
#        8.6519)
# val_loss tensor(1.00000e-02 *
#        7.4561)
# val_loss tensor(0.1148)
# val_loss tensor(0.1129)
# val_loss tensor(0.1382)
# val_loss tensor(0.1231)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:178, Average Score:0.53
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1124)
# val_loss tensor(0.1204)
# val_loss tensor(0.1138)
# val_loss tensor(0.1112)
# val_loss tensor(0.1241)
# val_loss tensor(0.1160)
# val_loss tensor(0.1220)
# val_loss tensor(0.1131)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:179, Average Score:0.53
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1194)
# val_loss tensor(0.1155)
# val_loss tensor(0.1324)
# val_loss tensor(0.1270)
# val_loss tensor(0.1136)
# val_loss tensor(0.1155)
# val_loss tensor(0.1394)
# val_loss tensor(0.1272)
# val_loss tensor(0.1137)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:180, Average Score:0.52
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1733)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:181, Average Score:0.52
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1161)
# val_loss tensor(0.1034)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:182, Average Score:0.52
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.7397)
# val_loss tensor(1.00000e-02 *
#        7.7456)
# val_loss tensor(1.00000e-02 *
#        8.1141)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:183, Average Score:0.52
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.6835)
# ...
#        8.6764)
# val_loss tensor(1.00000e-02 *
#        9.5533)
# val_loss tensor(1.00000e-02 *
#        8.6794)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1957, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.5689)
# val_loss tensor(1.00000e-02 *
#        7.7536)
# val_loss tensor(1.00000e-02 *
#        8.9845)
# val_loss tensor(1.00000e-02 *
#        7.4831)
# val_loss tensor(1.00000e-02 *
#        8.8700)
# val_loss tensor(1.00000e-02 *
#        9.1544)
# val_loss tensor(1.00000e-02 *
#        8.6145)
# val_loss tensor(1.00000e-02 *
#        4.0569)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1958, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.0838)
# val_loss tensor(1.00000e-02 *
#        7.4221)
# val_loss tensor(1.00000e-02 *
#        6.8358)
# val_loss tensor(1.00000e-02 *
#        7.6457)
# val_loss tensor(1.00000e-02 *
#        6.2413)
# val_loss tensor(1.00000e-02 *
#        8.3016)
# val_loss tensor(1.00000e-02 *
#        8.6525)
# val_loss tensor(1.00000e-02 *
#        6.0187)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1959, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.3664)
# val_loss tensor(1.00000e-02 *
#        9.8282)
# val_loss tensor(1.00000e-02 *
#        7.7847)
# val_loss tensor(1.00000e-02 *
#        6.3839)
# val_loss tensor(1.00000e-02 *
#        7.1529)
# val_loss tensor(1.00000e-02 *
#        8.4752)
# val_loss tensor(1.00000e-02 *
#        6.9062)
# val_loss tensor(1.00000e-02 *
#        8.1240)
# val_loss tensor(1.00000e-02 *
#        4.7242)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1960, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        4.4973)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1961, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.6359)
# val_loss tensor(1.00000e-02 *
#        9.3693)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1962, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.3150)
# val_loss tensor(1.00000e-02 *
#        6.8529)
# val_loss tensor(1.00000e-02 *
#        7.8730)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1963, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.6770)
# val_loss tensor(1.00000e-02 *
#        5.7682)
# val_loss tensor(1.00000e-02 *
#        8.0586)
# val_loss tensor(1.00000e-02 *
#        6.7375)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1964, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.6431)
# val_loss tensor(1.00000e-02 *
#        7.1229)
# val_loss tensor(1.00000e-02 *
#        6.4633)
# val_loss tensor(1.00000e-02 *
#        5.5770)
# val_loss tensor(1.00000e-02 *
#        5.3104)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1965, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.4939)
# val_loss tensor(1.00000e-02 *
#        9.7608)
# val_loss tensor(1.00000e-02 *
#        8.8997)
# val_loss tensor(1.00000e-02 *
#        8.6799)
# val_loss tensor(1.00000e-02 *
#        6.6273)
# val_loss tensor(1.00000e-02 *
#        5.5837)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1966, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.4295)
# val_loss tensor(1.00000e-02 *
#        8.1085)
# val_loss tensor(1.00000e-02 *
#        8.1158)
# val_loss tensor(1.00000e-02 *
#        7.8084)
# val_loss tensor(1.00000e-02 *
#        7.9439)
# val_loss tensor(1.00000e-02 *
#        9.1568)
# val_loss tensor(1.00000e-02 *
#        4.1077)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1967, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.2372)
# val_loss tensor(1.00000e-02 *
#        8.7621)
# val_loss tensor(1.00000e-02 *
#        8.6583)
# val_loss tensor(1.00000e-02 *
#        7.3968)
# val_loss tensor(1.00000e-02 *
#        7.1013)
# val_loss tensor(1.00000e-02 *
#        7.3758)
# val_loss tensor(1.00000e-02 *
#        7.5013)
# val_loss tensor(1.00000e-02 *
#        6.5582)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1968, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.3603)
# val_loss tensor(1.00000e-02 *
#        7.7077)
# val_loss tensor(1.00000e-02 *
#        6.2617)
# val_loss tensor(1.00000e-02 *
#        6.2920)
# val_loss tensor(1.00000e-02 *
#        6.9862)
# val_loss tensor(1.00000e-02 *
#        7.8141)
# val_loss tensor(1.00000e-02 *
#        6.8385)
# val_loss tensor(1.00000e-02 *
#        7.3547)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1969, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.0570)
# val_loss tensor(1.00000e-02 *
#        8.5184)
# val_loss tensor(1.00000e-02 *
#        8.3548)
# val_loss tensor(1.00000e-02 *
#        6.4754)
# val_loss tensor(1.00000e-02 *
#        6.3139)
# val_loss tensor(1.00000e-02 *
#        8.1183)
# val_loss tensor(1.00000e-02 *
#        5.6873)
# val_loss tensor(1.00000e-02 *
#        7.5988)
# val_loss tensor(1.00000e-02 *
#        8.8407)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1970, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.0120)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1971, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.1109)
# val_loss tensor(1.00000e-02 *
#        5.0395)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1972, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.8130)
# val_loss tensor(1.00000e-02 *
#        6.0860)
# val_loss tensor(1.00000e-02 *
#        7.4309)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1973, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.2644)
# val_loss tensor(1.00000e-02 *
#        6.4898)
# val_loss tensor(1.00000e-02 *
#        4.6757)
# val_loss tensor(1.00000e-02 *
#        5.1531)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1974, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.0312)
# val_loss tensor(1.00000e-02 *
#        6.6086)
# val_loss tensor(1.00000e-02 *
#        7.1621)
# val_loss tensor(1.00000e-02 *
#        5.8053)
# val_loss tensor(1.00000e-02 *
#        5.0685)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1975, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        5.8530)
# val_loss tensor(1.00000e-02 *
#        6.2907)
# val_loss tensor(1.00000e-02 *
#        6.2289)
# val_loss tensor(1.00000e-02 *
#        5.6555)
# val_loss tensor(1.00000e-02 *
#        5.6630)
# val_loss tensor(1.00000e-02 *
#        6.7260)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1976, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.5429)
# val_loss tensor(1.00000e-02 *
#        5.0724)
# val_loss tensor(1.00000e-02 *
#        6.0533)
# val_loss tensor(1.00000e-02 *
#        6.2982)
# val_loss tensor(1.00000e-02 *
#        5.6109)
# val_loss tensor(1.00000e-02 *
#        5.4984)
# val_loss tensor(1.00000e-02 *
#        5.3041)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1977, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.5644)
# val_loss tensor(1.00000e-02 *
#        6.7365)
# val_loss tensor(1.00000e-02 *
#        4.5881)
# val_loss tensor(1.00000e-02 *
#        6.4120)
# val_loss tensor(1.00000e-02 *
#        6.3416)
# val_loss tensor(1.00000e-02 *
#        6.6835)
# val_loss tensor(1.00000e-02 *
#        7.3622)
# val_loss tensor(1.00000e-02 *
#        2.6083)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1978, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.1910)
# val_loss tensor(1.00000e-02 *
#        7.2055)
# val_loss tensor(1.00000e-02 *
#        5.2358)
# val_loss tensor(1.00000e-02 *
#        6.5042)
# val_loss tensor(1.00000e-02 *
#        5.6417)
# val_loss tensor(1.00000e-02 *
#        6.0400)
# val_loss tensor(1.00000e-02 *
#        6.7195)
# val_loss tensor(1.00000e-02 *
#        7.9949)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1979, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        5.7248)
# val_loss tensor(1.00000e-02 *
#        6.2583)
# val_loss tensor(1.00000e-02 *
#        7.6903)
# val_loss tensor(1.00000e-02 *
#        7.1559)
# val_loss tensor(1.00000e-02 *
#        5.2173)
# val_loss tensor(1.00000e-02 *
#        5.7764)
# val_loss tensor(1.00000e-02 *
#        7.4975)
# val_loss tensor(1.00000e-02 *
#        7.4726)
# val_loss tensor(1.00000e-02 *
#        5.7185)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1980, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.2282)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1981, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.5846)
# val_loss tensor(1.00000e-02 *
#        7.8330)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1982, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.5477)
# val_loss tensor(1.00000e-02 *
#        7.2352)
# val_loss tensor(1.00000e-02 *
#        6.0155)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1983, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.4732)
# val_loss tensor(1.00000e-02 *
#        5.3188)
# val_loss tensor(1.00000e-02 *
#        6.4096)
# val_loss tensor(1.00000e-02 *
#        5.5830)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1984, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.2884)
# val_loss tensor(1.00000e-02 *
#        4.7546)
# val_loss tensor(1.00000e-02 *
#        5.0767)
# val_loss tensor(1.00000e-02 *
#        6.3561)
# val_loss tensor(1.00000e-02 *
#        6.8554)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1985, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.9648)
# val_loss tensor(1.00000e-02 *
#        6.1831)
# val_loss tensor(1.00000e-02 *
#        6.3737)
# val_loss tensor(1.00000e-02 *
#        5.0048)
# val_loss tensor(1.00000e-02 *
#        5.2542)
# val_loss tensor(1.00000e-02 *
#        7.2275)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1986, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        4.4583)
# val_loss tensor(1.00000e-02 *
#        5.7759)
# val_loss tensor(1.00000e-02 *
#        8.2834)
# val_loss tensor(1.00000e-02 *
#        6.5496)
# val_loss tensor(1.00000e-02 *
#        5.9228)
# val_loss tensor(1.00000e-02 *
#        6.2532)
# val_loss tensor(1.00000e-02 *
#        8.8927)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1987, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.4592)
# val_loss tensor(1.00000e-02 *
#        6.3418)
# val_loss tensor(1.00000e-02 *
#        7.1742)
# val_loss tensor(1.00000e-02 *
#        6.4639)
# val_loss tensor(1.00000e-02 *
#        7.3458)
# val_loss tensor(1.00000e-02 *
#        7.7092)
# val_loss tensor(1.00000e-02 *
#        6.8708)
# val_loss tensor(1.00000e-02 *
#        3.5117)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1988, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        5.9017)
# val_loss tensor(1.00000e-02 *
#        7.6603)
# val_loss tensor(1.00000e-02 *
#        5.8166)
# val_loss tensor(1.00000e-02 *
#        6.5453)
# val_loss tensor(1.00000e-02 *
#        8.0767)
# val_loss tensor(1.00000e-02 *
#        6.2196)
# val_loss tensor(1.00000e-02 *
#        9.5244)
# val_loss tensor(1.00000e-02 *
#        9.3861)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1989, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.8258)
# val_loss tensor(1.00000e-02 *
#        5.4536)
# val_loss tensor(1.00000e-02 *
#        8.8508)
# val_loss tensor(1.00000e-02 *
#        8.0624)
# val_loss tensor(1.00000e-02 *
#        6.7284)
# val_loss tensor(1.00000e-02 *
#        6.7148)
# val_loss tensor(1.00000e-02 *
#        8.0540)
# val_loss tensor(1.00000e-02 *
#        7.5759)
# val_loss tensor(1.00000e-02 *
#        8.1045)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1990, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(0.1485)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1991, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.2936)
# val_loss tensor(1.00000e-02 *
#        9.8585)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1992, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        9.1241)
# val_loss tensor(1.00000e-02 *
#        6.6960)
# val_loss tensor(0.1038)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1993, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.6814)
# val_loss tensor(1.00000e-02 *
#        7.7076)
# val_loss tensor(1.00000e-02 *
#        9.3572)
# val_loss tensor(1.00000e-02 *
#        7.2260)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1994, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.5979)
# val_loss tensor(1.00000e-02 *
#        8.3785)
# val_loss tensor(1.00000e-02 *
#        6.3257)
# val_loss tensor(1.00000e-02 *
#        8.6812)
# val_loss tensor(1.00000e-02 *
#        7.7024)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1995, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        6.0331)
# val_loss tensor(1.00000e-02 *
#        9.2575)
# val_loss tensor(1.00000e-02 *
#        6.7077)
# val_loss tensor(1.00000e-02 *
#        8.0078)
# val_loss tensor(1.00000e-02 *
#        7.1795)
# val_loss tensor(1.00000e-02 *
#        4.7715)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1996, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.2213)
# val_loss tensor(1.00000e-02 *
#        6.4532)
# val_loss tensor(1.00000e-02 *
#        9.0737)
# val_loss tensor(1.00000e-02 *
#        8.2482)
# val_loss tensor(1.00000e-02 *
#        6.9161)
# val_loss tensor(1.00000e-02 *
#        6.7569)
# val_loss tensor(1.00000e-02 *
#        8.8428)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1997, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        8.6949)
# val_loss tensor(1.00000e-02 *
#        7.8778)
# val_loss tensor(1.00000e-02 *
#        7.6851)
# val_loss tensor(1.00000e-02 *
#        9.4275)
# val_loss tensor(1.00000e-02 *
#        8.4869)
# val_loss tensor(1.00000e-02 *
#        6.9417)
# val_loss tensor(1.00000e-02 *
#        7.4148)
# val_loss tensor(1.00000e-02 *
#        2.3247)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1998, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        5.8179)
# val_loss tensor(1.00000e-02 *
#        8.9662)
# val_loss tensor(1.00000e-02 *
#        7.8875)
# val_loss tensor(1.00000e-02 *
#        7.1270)
# val_loss tensor(1.00000e-02 *
#        8.5077)
# val_loss tensor(1.00000e-02 *
#        8.6357)
# val_loss tensor(1.00000e-02 *
#        6.5314)
# val_loss tensor(1.00000e-02 *
#        7.1931)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:1999, Average Score:0.10
# PPO step 0
# PPO step 1
# PPO step 2
# PPO step 3
# PPO step 4
# val_loss tensor(1.00000e-02 *
#        7.2102)
# val_loss tensor(1.00000e-02 *
#        6.1146)
# val_loss tensor(1.00000e-02 *
#        6.1140)
# val_loss tensor(1.00000e-02 *
#        7.4959)
# val_loss tensor(1.00000e-02 *
#        6.0818)
# val_loss tensor(1.00000e-02 *
#        7.7095)
# val_loss tensor(1.00000e-02 *
#        7.5243)
# val_loss tensor(1.00000e-02 *
#        7.9880)
# val_loss tensor(1.00000e-02 *
#        8.2926)
# PPO step 5
# PPO step 6
# PPO step 7
# Episode:2000, Average Score:0.10

# %%
import torch
from collections import deque
from time import sleep

num_agents=20
agent = Agent(state_size=state_size, action_size=action_size, random_seed=0)

agent.actor_local.load_state_dict(torch.load('checkpoint_actor_ppo449.pth'))
agent.critic_local.load_state_dict(torch.load('checkpoint_critic_ppo449.pth'))


env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
cur_states = env_info.vector_observations  
scores_agents = np.zeros(num_agents)

for step in range(1100):
    actions = agent.act(cur_states)[0]
    env_info = env.step(actions)[brain_name]     
    next_states = env_info.vector_observations   
    rewards = env_info.rewards                   
    dones = env_info.local_done                  
    cur_states = next_states
    scores_agents += rewards
    if np.any(dones):
        break

            
env.close()

# %% [markdown]
# When finished, you can close the environment.

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
